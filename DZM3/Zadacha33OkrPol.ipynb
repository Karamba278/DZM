# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math

x3 = []
y3 = []
r=10
for i in range(1, 360):
    a=math.radians(i)
    x3.append(r*np.cos(a))
    y3.append(r*np.sin(a))
plt.axes().set_aspect('equal')
plt.plot(x3,y3)
