# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math

x3 = []
y3 = []
x4 = []
y4 = []
x5 = []
y5 = []
x6 = []
y6 = []
for i in range(10000):
    x_ = i/1000
    x3.append(x_)
    y3.append(math.sqrt(10*10-x_*x_))
    x4.append(-x_)
    y4.append(math.sqrt(10*10-x_*x_))
    x5.append(x_)
    y5.append((-math.sqrt(10*10-x_*x_)))
    x6.append(-x_)
    y6.append((-math.sqrt(10*10-x_*x_)))
plt.axes().set_aspect('equal')
plt.plot(x3,y3)
plt.plot(x4,y4)
plt.plot(x5,y5)
plt.plot(x6,y6)
