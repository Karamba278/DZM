# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math

from scipy.optimize import fsolve

def equations(p):
    x, y = p
    return (y - x**2 + 1, np.exp(x) - x*y + x - 1)

x1, y1 =  fsolve(equations, (-2, 1))


x0=float(input('Введите значение Х, для которого Вы хотите найти Y'))
y0= x0**2-1
if y0<((np.exp(x0)+x0-1)/x0):
    print (x0, y0)
else: 
    print (f'Значение Y для искомого Х ({x0}) - выходят за рамки допустимого диапазона y<(exp(x)+x-1)/x')
    
    print (f'Исходя из существующей системы неравенств, Вы должны указать X>{x1}')
x = np.linspace(-3, 3, 201)
plt.plot(x, x**2-1)
plt.plot(x, (np.exp(x) + x - 1)/x)
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-1,5) 
plt.grid(True)
plt.show()
print (x0,y0)
# Out:
# Введите значение Х, для которого Вы хотите найти Y-1.5
# -1.5 1.25
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in true_divide
# -1.5 1.25
